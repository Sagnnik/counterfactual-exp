# %%
import subprocess
import os
import cv2
from time import sleep
import glob
'''
file_path = 'annotations/icqa_dataset/IID/json/example_3.json'
#file_name = 'example_3.json' 
#file_path = os.path.join(path, file_name)
print(file_path)

subprocess.run(["python", "recreate2.py", "--jsonold", file_path])
'''
filename = 'example_24'
frameSize = (1024, 1024)
out = cv2.VideoWriter(f'{filename}.mp4',cv2.VideoWriter_fourcc(*'mp4v'), 25, frameSize)
for filename in glob.glob('saved_imgs/*.png'):
    img = cv2.imread(filename)
    out.write(img)
out.release()
print(f"Generated : {filename}")
# Out:
# Generated : saved_imgs\img_0124.png
